# %%
# !pip install pandas
# !pip install numpy
# !pip install scipy
# !pip install sklearn
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy>=1.17.3 in d:\anaconda\lib\site-packages (from pandas) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in d:\anaconda\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (1.21.4)
# Requirement already satisfied: scipy in d:\anaconda\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in d:\anaconda\lib\site-packages (from scipy) (1.21.4)
# Requirement already satisfied: sklearn in d:\anaconda\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in d:\anaconda\lib\site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda\lib\site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in d:\anaconda\lib\site-packages (from scikit-learn->sklearn) (1.7.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: numpy>=1.14.6 in d:\anaconda\lib\site-packages (from scikit-learn->sklearn) (1.21.4)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: numpy>=1.16 in d:\anaconda\lib\site-packages (from matplotlib) (1.21.4)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np # for performing mathematical calculations behind ML algorithms
import matplotlib.pyplot as plt # for visualization
import pandas as pd # for handling and cleaning the dataset
import seaborn as sns # for visualization
import sklearn # for model evaluation and development

# %% [markdown]
# # Importing the Dataset

# %%
data=pd.read_csv('Add_sales_data_2018.csv')

# %% [markdown]
# # Analyzing the data

# %%
data.head()
# Out:
#          Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 0  2018-10-08              208.00              222.25              206.85
# 1  2018-10-05              217.00              218.60              205.90
# 2  2018-10-04              223.50              227.80              216.15
# 3  2018-10-03              230.00              237.50              225.75
# 4  2018-10-01              234.55              234.60              221.05
#
#    Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# 0              216.00              215.15              4093.065
# 1              210.25              209.20              4042.448
# 2              217.25              218.20              4213.819
# 3              226.45              227.60              4391.665
# 4              230.30              230.90              4350.683

# %%
data.tail()
# Out:
#            Date  Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# 200  2017-12-14              288.00              288.25              279.20
# 201  2017-12-13              290.00              292.50              282.20
# 202  2017-12-12              298.60              298.60              286.65
# 203  2017-12-11              290.00              299.55              285.90
# 204  2017-12-08              287.55              289.90              285.05
#
#      Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# 200              284.50              284.30              5374.105
# 201              284.80              284.45              5439.655
# 202              287.45              287.80              5545.013
# 203              297.85              298.35              5565.444
# 204              288.05              288.45              5421.842

# %% [markdown]
# # Numerical/Statistical analysis of the dataset

# %%
data.describe()
# Out:
#        Add1(in Thousands)  Add2(in Thousands)  Add3(in Thousands)  \
# count          205.000000          205.000000          205.000000
# mean           267.577561          271.722439          262.990732
# std             26.219588           25.914939           26.126704
# min            208.000000          218.600000          205.900000
# 25%            244.000000          248.500000          240.300000
# 50%            269.700000          274.200000          263.250000
# 75%            284.400000          288.800000          280.900000
# max            327.700000          328.750000          321.650000
#
#        Add4(in Thousands)  Add5(in Thousands)  Profit(in Thousands)
# count          205.000000          205.000000            205.000000
# mean           267.223902          267.152683           5059.630234
# std             26.238832           26.215360            486.910414
# min            210.250000          209.200000           4042.448000
# 25%            243.050000          243.000000           4617.695000
# 50%            268.900000          268.350000           5088.455000
# 75%            284.500000          284.450000           5387.438000
# max            325.950000          325.750000           6137.800000

# %% [markdown]
# # Dimensions of dataset

# %%
print('There are ',data.shape[0],'rows and ',data.shape[1],'columns in the dataset.')
# Out:
# There are  205 rows and  7 columns in the dataset.

# %% [markdown]
# # Checking if there are repeated values in the dataset or not.

# %%
print('There are',data.duplicated().sum(),'duplicate values in the dateset.') #using duplicated() pre-defined function
# Out:
# There are 0 duplicate values in the dateset.

# %% [markdown]
# # Check for NULL values

# %%
data.isnull().sum()
# Out:
# Date                    0
# Add1(in Thousands)      0
# Add2(in Thousands)      0
# Add3(in Thousands)      0
# Add4(in Thousands)      0
# Add5(in Thousands)      0
# Profit(in Thousands)    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  205 non-null    object
#  1   Add1(in Thousands)    205 non-null    float64
#  2   Add2(in Thousands)    205 non-null    float64
#  3   Add3(in Thousands)    205 non-null    float64
#  4   Add4(in Thousands)    205 non-null    float64
#  5   Add5(in Thousands)    205 non-null    float64
#  6   Profit(in Thousands)  205 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 11.3+ KB

# %% [markdown]
# # 1. First of all, check whether there is any relationship between the amount spent for advertising through five different companies and profit generated.

# %% [markdown]
# # Correlation between Variables

# %%
c = data.corr()
c
# Out:
#                       Add1(in Thousands)  Add2(in Thousands)  \
# Add1(in Thousands)              1.000000            0.990976
# Add2(in Thousands)              0.990976            1.000000
# Add3(in Thousands)              0.986274            0.987990
# Add4(in Thousands)              0.976365            0.989921
# Add5(in Thousands)              0.976716            0.990285
# Profit(in Thousands)            0.991975            0.999145
#
#                       Add3(in Thousands)  Add4(in Thousands)  \
# Add1(in Thousands)              0.986274            0.976365
# Add2(in Thousands)              0.987990            0.989921
# Add3(in Thousands)              1.000000            0.991343
# Add4(in Thousands)              0.991343            1.000000
# Add5(in Thousands)              0.991908            0.999699
# Profit(in Thousands)            0.993389            0.993346
#
#                       Add5(in Thousands)  Profit(in Thousands)
# Add1(in Thousands)              0.976716              0.991975
# Add2(in Thousands)              0.990285              0.999145
# Add3(in Thousands)              0.991908              0.993389
# Add4(in Thousands)              0.999699              0.993346
# Add5(in Thousands)              1.000000              0.993710
# Profit(in Thousands)            0.993710              1.000000

# %% [markdown]
# # Correlaion Matrix

# %%
plt.subplots(figsize=(20,8))
sns.heatmap(c,vmin=0.98,vmax=1,annot=True,linewidth=0.2,cmap='Blues')
plt.show()

# %% [markdown]
# Inference: Here we can see the direct correlation with profit from how it is shown in the heatmap of the correlation plot.

# %% [markdown]
# # Outliers detection in the target variable

# %%
outliers = ['Profit(in Thousands)']
plt.rcParams['figure.figsize'] = [8,8]
sns.boxplot(data=data[outliers], orient="v", palette="Set2" , width=0.7) # orient = "v" : vertical boxplot , 
                                                                            # orient = "h" : hotrizontal boxplot
plt.title("Outliers Variable Distribution")
plt.ylabel("Profit Range")
plt.xlabel("Continuous Variable")

plt.show()

# %% [markdown]
# There is no outliners in the profit

# %% [markdown]
# # Histogram on Profit

# %%
data['Profit(in Thousands)'].mean()
# Out:
# 5059.630234146345

# %%
sns.distplot(data['Profit(in Thousands)'],bins=5,kde=True)
plt.show()
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Inference: The average profit (which is 5059.630234146345) is the most frequent i.e. this should be in the category of distribution plot.

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# Inference: As we can see in the pair pot, Add1,Add2,Add3,Add4,Add5 are directly proportional to the Profit.

# %% [markdown]
# # 2. Build a regression model to predict the profit from the given data and comment your findings on it.

# %% [markdown]
# # Model Development

# %%
# spliting Dataset in Dependent & Independent Variables
y=data['Profit(in Thousands)']
x=data.drop(['Profit(in Thousands)','Date'], axis=1)

# %% [markdown]
# # Transforming Data

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder = LabelEncoder()
x[:, 4] = labelencoder.fit_transform(x[:, 4])
x1 = pd.DataFrame(x)
x1.head()
# Out:
#           0         1         2         3     4
# 0 -2.277816 -1.913705 -2.154048 -1.956996   1.0
# 1 -1.933721 -2.054895 -2.190498 -2.176674   0.0
# 2 -1.685208 -1.699019 -1.797219 -1.909240   3.0
# 3 -1.436695 -1.323801 -1.428879 -1.557757  10.0
# 4 -1.262736 -1.435979 -1.609212 -1.410668  11.0

# %% [markdown]
# Label Encoder: Encode labels with values between 0 and n_classes-1.

# %% [markdown]
# # Splitting the data into training and testing data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=0)

# %% [markdown]
# # Creating a Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
print('Model has been trained successfully')
# Out:
# Model has been trained successfully

# %% [markdown]
# # Testing the model using the predict function

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([4493.47542856, 5920.85009344, 4404.17132667, 4191.09690104,
#        5879.77225207, 5728.4570995 , 5225.36004129, 5017.20708115,
#        5518.50048803, 4514.5361669 , 4464.39298983, 5140.62769522,
#        4761.56856215, 5037.99679605, 4607.62537166, 5730.96667017,
#        4923.06764543, 4471.13003287, 4480.41404804, 5065.87262887,
#        5043.58147256, 5491.86622825, 4967.8976588 , 5793.23985066,
#        6137.89418531, 5247.28949028, 5138.01498476, 5374.12238274,
#        5213.37460243, 4899.20400427, 5971.73736355, 5745.17536898,
#        5153.91448113, 5805.56140576, 4763.55197181, 4176.42171369,
#        5938.64392781, 4916.05059941, 4524.26789701, 5113.25546156,
#        4648.76843873, 4349.25380038, 4915.60907176, 4934.63640283,
#        5108.50571914, 5167.75877526, 4451.53594637, 4979.96786764,
#        5177.62422586, 5861.32146427, 4424.94578227, 4887.08668579,
#        5267.58280364, 5088.5390181 , 5163.28317753, 5430.92149939,
#        5251.10136638, 5435.65902408, 5134.70214505, 4435.90197787,
#        4598.58644551, 4978.98247052])

# %%
testing_data_model_score = model.score(x_test, y_test)
print("Model Score/Performance on Testing data",testing_data_model_score)

training_data_model_score = model.score(x_train, y_train)
print("Model Score/Performance on Training data",training_data_model_score)
# Out:
# Model Score/Performance on Testing data 0.9999990697791231
# Model Score/Performance on Training data 0.9999987359578061

# %% [markdown]
# # Comparing the predicted values and actual values

# %%
df = pd.DataFrame(data={'Predicted value':y_pred,'Actual Value':y_test})
df
# Out:
#      Predicted value  Actual Value
# 52       4493.475429      4494.144
# 181      5920.850093      5921.116
# 5        4404.171327      4404.686
# 18       4191.096901      4190.965
# 188      5879.772252      5880.541
# ..               ...           ...
# 198      5435.659024      5435.316
# 143      5134.702145      5134.657
# 24       4435.901978      4435.174
# 30       4598.586446      4598.292
# 135      4978.982471      4979.399
#
# [62 rows x 2 columns]

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import r2_score
r2Score = r2_score(y_pred, y_test)
print("R2 score of model is :" ,r2Score*100)
# Out:
# R2 score of model is : 99.99990695124254

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_pred, y_test)
print("Mean Squarred Error is :" ,mse*100)
# Out:
# Mean Squarred Error is : 22.16734824761506

# %%
rmse = np.sqrt(mean_squared_error(y_pred, y_test))
print("Root Mean Squarred Error is : ",rmse*100)
# Out:
# Root Mean Squarred Error is :  47.08221346497535

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_pred,y_test)
print("Mean Absolute Error is :" ,mae)
# Out:
# Mean Absolute Error is : 0.35608895506550564

# %% [markdown]
# # 3. Predict the profit generated by the company, if they wish to spend the following amount for advertisement.

# %%
predict_profit_for= np.array([[219],[312],[309],[298],[320]])

# %%
predict_profit_for=predict_profit_for.reshape(1,5)

# %%
profit=model.predict(predict_profit_for)

# %%
profit[0]
# Out:
# 153526.522677657

# %% [markdown]
# Therefore the predicted Profit(in Thousands) for the values Add1(in Thousands)=290,Add2(in Thousands)=312,Add3(in Thousands)=309,Add4(in Thousands)=298,Add5(in Thousands)=320 is 153526.522677657.

# %% [markdown]
# # Conclusion

# %% [markdown]
# So, the mean absolute error is 0.35608895506550564. Therefore our predicted value can be 0.35608895506550564 units more or less than the actual value.
